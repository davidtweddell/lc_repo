# %%
# reload magics
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from project_modules.utils import get_logger
logger = get_logger("log-data-description.log")
# read the parameter file

from project_modules.utils import read_parameters
parms = read_parameters("/Users/david/projects/lc-project-data/project.yaml")
# Out:
# [2024-04-03 08:39:16] [get_logger] Logger initialized.
# [2024-04-03 08:39:16] [get_logger] Logging to file: log-data-description.log
# [2024-04-03 08:39:16] [read_parameters] Reading parameters.
# [2024-04-03 08:39:16] [read_parameters] ... reading /Users/david/projects/lc-project-data/project.yaml
# ==================================================

# %%
# TODO: use the same readers as in 01 and 03

# %%
from pathlib import Path
input_dir = Path(parms["dir_proc_data"])
ipath = Path(input_dir / "SYNTHETIC_dataset_dict")
ipath
# Out:
# PosixPath('/Users/david/projects/lc-project-data/processed-data/SYNTHETIC_dataset_dict')

# %%
from project_modules.io import load_dataset_to_df
df = load_dataset_to_df(ipath, verbose = True)
# Out:
# [2024-04-03 08:39:16] [load_dataset_to_df] Loading data from /Users/david/projects/lc-project-data/processed-data/SYNTHETIC_dataset_dict...
# [2024-04-03 08:39:16] [load_dataset_to_df] Converting to dataframe...
# [2024-04-03 08:39:16] [load_dataset_to_df] Shape: (1000, 26)

# %%
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.302613  0.521123  0.191500  0.467359  0.626975  0.677870  0.753331
# 1    0.257804  0.464267  0.330466  0.532893  0.729430  0.770717  0.888336
# 2    0.394052  0.800682  0.785214  0.538753  0.650675  0.194084  0.311329
# 3    0.621795  0.508659  0.552044  0.661753  0.295243  0.677640  0.495681
# 4    0.729019  0.601845  0.370868  0.463596  0.317109  0.729907  0.389768
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.493270  0.640824  0.484019  0.196135  0.568049  0.300156  0.567978
# 996  0.297912  0.631257  0.459269  0.363111  0.651425  0.665161  0.720415
# 997  0.497951  0.635500  0.226033  0.403830  0.664612  0.489009  0.692819
# 998  0.250651  0.466783  0.635386  0.167288  0.666328  0.188471  0.209728
# 999  0.725502  0.435466  0.527146  0.298298  0.405941  0.604866  0.321503
#
#             7         8         9  ...        16        17        18  \
# 0    0.507630  0.544143  0.825604  ...  0.799275  0.601659  0.438513
# 1    0.676928  0.375975  0.676806  ...  0.549494  0.600223  0.455256
# 2    0.408104  0.259455  0.250866  ...  0.398946  0.338611  0.665744
# 3    0.758101  0.496506  0.260641  ...  0.176250  0.415677  0.571625
# 4    0.617932  0.783749  0.486733  ...  0.224738  0.536366  0.688825
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.274078  0.405254  0.446272  ...  0.433255  0.409837  0.762957
# 996  0.345679  0.283786  0.756290  ...  0.723360  0.454465  0.610155
# 997  0.601036  0.445902  0.837343  ...  0.640714  0.503117  0.387628
# 998  0.735907  0.000000  0.223256  ...  0.352970  0.370881  0.621669
# 999  0.419857  0.628584  0.352035  ...  0.185472  0.415548  0.444796
#
#            19        20        21        22        23        24  TRUE_LABEL
# 0    0.769452  0.548487  0.625004  0.363331  0.436184  0.362942           1
# 1    0.594623  0.489756  0.288183  0.279042  0.651704  0.189517           1
# 2    0.307852  0.565110  0.524678  0.305794  0.436908  0.642480           2
# 3    0.292897  0.164464  0.215708  0.630206  0.575802  0.477226           0
# 4    0.424784  0.597594  0.427864  0.757168  0.573307  0.748528           0
# ..        ...       ...       ...       ...       ...       ...         ...
# 995  0.320934  0.334321  0.569592  0.262952  0.371271  0.627672           2
# 996  0.462536  0.710052  0.360692  0.167789  0.780653  0.459158           1
# 997  0.827664  0.509562  0.626271  0.284980  0.641577  0.034741           1
# 998  0.203574  0.469700  0.426567  0.400837  0.565400  0.655035           2
# 999  0.458051  0.663345  0.149400  0.605026  0.286799  0.460644           0
#
# [1000 rows x 26 columns]
