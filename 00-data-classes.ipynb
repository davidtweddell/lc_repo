# %%
from pathlib import Path
import colorcet as cc
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

from datasets import load_dataset, Dataset, load_from_disk

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


# set some defaults
warnings.filterwarnings("ignore")
np.set_printoptions(precision=4, 
                    floatmode='fixed')
pd.set_option('display.precision', 3)

# set default font size for matplotlib
plt.rcParams.update({'font.size': 12,})
# set default font
plt.rcParams['font.family'] = 'Roboto'

heatmap_parms = {
                # 'linewidths' : 0.5,
                'linecolor' : 'white',
                'cmap' : cc.cm.bkr,
                }

# %%
# read in the LCOPT-data-dict

data_dict = pd.read_excel('./LCOPT-data-dict.xlsx')

# %%
data_dict
# Out:
#                      FIELD_NAME     FORM_NAME  KEEP DTYPE COMMENT IDEAS  \
# 0                     record_id  consent_form   1.0   NaN   UUID?   NaN
# 1                   lawson_logo  consent_form   0.0   NaN     NaN   NaN
# 2                         title  consent_form   0.0   NaN     NaN   NaN
# 3                       pi_name  consent_form   0.0   NaN     NaN   NaN
# 4                        loi_10  consent_form   0.0   NaN     NaN   NaN
# ..                          ...           ...   ...   ...     ...   ...
# 347                       label   biospecimen   0.0   NaN     NaN   NaN
# 348         datetime_collection   biospecimen   0.0   NaN     NaN   NaN
# 349           datetime_freezing   biospecimen   0.0   NaN     NaN   NaN
# 350                    aliquots   biospecimen   0.0   NaN     NaN   NaN
# 351  biospecimen_collection_not   biospecimen   0.0   NaN     NaN   NaN
#
#       FIELD_TYPE                                        Field Label  \
# ...

# %%
# drop all FIELD_TYPE == descriptive
data_dict = data_dict[data_dict['FIELD_TYPE'] != 'Descriptive']

data_dict.value_counts('FORM_NAME')
# Out:
# FORM_NAME
# clinical_details                            121
# clinical_tests                               58
# covid19_details                              39
# consent_form                                 36
# promis_29_profile_v20                        29
# phx                                          19
# demographics                                 13
# generalized_anxiety_disorder_7_item_gad7     13
# biospecimen                                  11
# patient_health_questionnaire_9               11
# clinical_note                                 2
# Name: count, dtype: int64
